# %% [markdown]
# #  Basic Python Libraries

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading The DataSets

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %% [markdown]
# # Initial Analysis On the Train DataSet

# %%
train_df.shape, test_df.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA) ON TRAIN DATASET

# %%
null_values = [
    col for col in train_df.columns 
    if train_df[col].isnull().any()
]

# %%
null_values
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
train_df[null_values].isnull().sum()
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
train_df = train_df.drop(columns = ["LotFrontage","Alley","MasVnrType","FireplaceQu", "PoolQC", "Fence", "MiscFeature"])
test_df = test_df.drop(columns = ["LotFrontage","Alley","MasVnrType","FireplaceQu", "PoolQC", "Fence", "MiscFeature"])

# %%
null_values = [
    col for col in train_df.columns 
    if train_df[col].isnull().any()
]
train_df[null_values].isnull().sum()
# Out:
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
train_df[null_values].dtypes
# Out:
# MasVnrArea      float64
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Electrical       object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# dtype: object

# %%
clean_train_df = train_df.dropna()
clean_train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
# ...

# %%
clean_train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
# ...

# %%
categorical_data = clean_train_df.select_dtypes(include = ['object']).columns
print(categorical_data)
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
numerical_data = clean_train_df.select_dtypes(exclude = ['object']).columns
print(numerical_data)
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
clean_train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
# ...

# %% [markdown]
# # Handling Categorical Variables

# %%
clean_train_df_copy = clean_train_df.copy()

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
categorical_col = low_cardinality + high_cardinality
for col in categorical_col:
    clean_train_df[col] = label.fit_transform(clean_train_df[col])

# %%
clean_train_df.shape
# Out:
# (1338, 74)

# %% [markdown]
# # TEST DATASET

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 73 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   object
#  5   LotShape       1459 non-null   object
#  6   LandContour    1459 non-null   object
#  7   Utilities      1457 non-null   object
#  8   LotConfig      1459 non-null   object
#  9   LandSlope      1459 non-null   object
#  10  Neighborhood   1459 non-null   object
#  11  Condition1     1459 non-null   object
#  12  Condition2     1459 non-null   object
#  13  BldgType       1459 non-null   object
#  14  HouseStyle     1459 non-null   object
#  15  OverallQual    1459 non-null   int64
#  16  OverallCond    1459 non-null   int64
# ...

# %%
test_df.describe()
# Out:
#                 Id   MSSubClass       LotArea  OverallQual  OverallCond  \
# count  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# mean   2190.000000    57.378341   9819.161069     6.078821     5.553804
# std     421.321334    42.746880   4955.517327     1.436812     1.113740
# min    1461.000000    20.000000   1470.000000     1.000000     1.000000
# 25%    1825.500000    20.000000   7391.000000     5.000000     5.000000
# 50%    2190.000000    50.000000   9399.000000     6.000000     5.000000
# 75%    2554.500000    70.000000  11517.500000     7.000000     6.000000
# max    2919.000000   190.000000  56600.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1459.000000   1459.000000  1444.000000  1458.000000  1458.000000
# mean   1971.357779   1983.662783   100.709141   439.203704    52.619342
# std      30.390071     21.130467   177.625900   455.268042   176.753926
# ...

# %%
test_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
null_values = [
    col for col in test_df.columns
    if test_df[col].isnull().any()
]
test_df[null_values].isnull().sum()
# Out:
# MSZoning         4
# Utilities        2
# Exterior1st      1
# Exterior2nd      1
# MasVnrArea      15
# BsmtQual        44
# BsmtCond        45
# BsmtExposure    44
# BsmtFinType1    42
# BsmtFinSF1       1
# BsmtFinType2    42
# BsmtFinSF2       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# BsmtFullBath     2
# BsmtHalfBath     2
# KitchenQual      1
# Functional       2
# GarageType      76
# GarageYrBlt     78
# GarageFinish    78
# GarageCars       1
# GarageArea       1
# GarageQual      78
# GarageCond      78
# SaleType         1
# dtype: int64

# %%
test_df[null_values].dtypes
# Out:
# MSZoning         object
# Utilities        object
# Exterior1st      object
# Exterior2nd      object
# MasVnrArea      float64
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinSF1      float64
# BsmtFinType2     object
# BsmtFinSF2      float64
# BsmtUnfSF       float64
# TotalBsmtSF     float64
# BsmtFullBath    float64
# BsmtHalfBath    float64
# KitchenQual      object
# Functional       object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageCars      float64
# GarageArea      float64
# GarageQual       object
# GarageCond       object
# SaleType         object
# dtype: object

# %%
clean_test_df = test_df.apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
clean_test_df[clean_test_df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %% [markdown]
# # Examining Unique Values in Test Dataset

# %%
for col in categorical_col:
    clean_test_df[col] = label.fit_transform(clean_test_df[col])

# %%
clean_test_df.head()
# Out:
#      Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 0  1461          20         2    11622       1         3            3
# 1  1462          20         3    14267       1         0            3
# 2  1463          60         3    13830       1         0            3
# 3  1464          60         3     9978       1         0            3
# 4  1465         120         3     5005       1         0            1
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0            12           1           2
# 1          0          0          0            12           2           2
# 2          0          4          0             8           2           2
# 3          0          4          0             8           2           2
# 4          0          4          0            22           2           2
#
#    BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# ...

# %% [markdown]
# # Separating Data into Test and Training Set.

# %%
from sklearn.model_selection import train_test_split

# %%
X = clean_train_df.drop(['SalePrice'], axis = 1)
y = clean_train_df[['SalePrice']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)

# %%
X_train.head()
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 851    852         120         3     3196       1         3            3
# 549    550          60         1     9375       1         3            3
# 164    165          40         4     5400       1         3            3
# 1006  1007          20         3    12155       1         2            3
# 183    184          50         4    11426       1         3            3
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 851           0          4          0             0           2           2
# 549           0          4          0            21           2           2
# 164           0          0          0            17           2           2
# 1006          0          4          0            12           4           2
# 183           0          4          0            17           2           2
#
# ...

# %%
y_train.head()
# Out:
#       SalePrice
# 851      215000
# 549      263000
# 164      152000
# 1006     163500
# 183      200000

# %%
X_train.shape, X_test.shape
# Out:
# ((1070, 73), (268, 73))

# %%
print(f"X_train: {X_train.shape[0]}")
print(f"X_test: {X_test.shape[0]}")
print(f"y_train: {y_train.shape[0]}")
print(f"y_test: {y_test.shape[0]}")
# Out:
# X_train: 1070
# X_test: 268
# y_train: 1070
# y_test: 268

# %% [markdown]
# # MODELLING

# %% [markdown]
# Logistic Regression Algorithm

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
log_reg = LogisticRegression()
log_reg
# Out:
# LogisticRegression()

# %%
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_reg.predict(X_test)

# %%
y_pred
# Out:
# array([148000, 178000, 100000, 167000, 125000, 165000, 129000, 155000,
#        190000, 125000, 275000, 210000, 130000, 180000, 143000, 227000,
#        227000, 110000, 110000, 148000, 189000, 110000, 248000, 143000,
#        141000, 135000, 139000, 228950, 180500, 144000, 207500, 325000,
#        187500, 125000, 180000, 235000, 145000, 145000, 135000, 205000,
#        196000, 180000, 178000, 171000, 124000, 144000, 110000,  88000,
#        119000, 144000, 178000, 160000, 124000, 155000, 200000, 185000,
#        275000, 225000, 239000, 189000, 125000, 132500, 110000, 270000,
#        295000, 190000, 119000, 180000, 195000, 119000, 202500, 178000,
#        144000, 205000, 179400, 180000, 180000, 202500,  88000, 119000,
#        110000, 144000, 149900, 137500, 110000, 140000, 190000, 179400,
#        225000, 110000, 180000, 205000, 135000, 178000, 189000, 135000,
#        187500, 190000, 260000, 180000, 110000, 135000, 235000, 135000,
# ...

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy: {}".format(accuracy))
# Out:
# Test Accuracy: 0.022388059701492536

# %% [markdown]
# Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dec_tree = DecisionTreeClassifier(random_state= 5)

# %%
dec_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=5)

# %%
y_pred = dec_tree.predict(X_test)

# %%
print("The test accuracy of Decision Tree is:", accuracy_score(y_test, y_pred))
# Out:
# The test accuracy of Decision Tree is: 0.007462686567164179

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(dec_tree, X_test, y_test, cv = 5)
print("Cross-Validation Accuracy Scores", scores.mean())
# Out:
# Cross-Validation Accuracy Scores 0.0037735849056603774

# %% [markdown]
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()

# %%
dtr.fit(X_train, y_train)
dtr_pred = dtr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

dtr_error = mean_absolute_error(y_test, dtr_pred)
dtr_error
# Out:
# 28419.123134328358

# %%
dtr_percentage_error = mean_absolute_percentage_error(y_test, dtr_pred)
dtr_percentage_error * 100
# Out:
# 15.472487516236466

# %% [markdown]
# Support Vector Machines

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC(random_state = 5)

# %%
svc_model.fit(X_train, y_train)
# Out:
# SVC(random_state=5)

# %%
y_pred = svc_model.predict(X_test)

# %%
print("The test accuracy score of SVM is:", accuracy_score(y_test, y_pred))
# Out:
# The test accuracy score of SVM is: 0.0037313432835820895

# %%
scores = cross_val_score(svc_model, X_test, y_test, cv = 5)
print("Cross-Validation Accuracy Score:", scores.mean())
# Out:
# Cross-Validation Accuracy Score: 0.029839273235499647

# %% [markdown]
# Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest = RandomForestClassifier(random_state = 5)

# %%
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=5)

# %%
y_pred = random_forest.predict(X_test)

# %%
print("The test accuracy score of Random Forest is", accuracy_score(y_test, y_pred))
# Out:
# The test accuracy score of Random Forest is 0.011194029850746268

# %%
scores = cross_val_score(random_forest, X_test, y_test, cv = 5)
print("Cross-Validation Accuracy Scores", scores.mean())
# Out:
# Cross-Validation Accuracy Scores 0.0037037037037037034

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()

# %%
rfr.fit(X_train, y_train)
rfr_pred = rfr.predict(X_test)

# %%
rfr_error = mean_absolute_error(y_test, rfr_pred)
rfr_error
# Out:
# 18166.70432835821

# %%
rfr_percentage_error = mean_absolute_percentage_error(y_test, rfr_pred)
rfr_percentage_error * 100
# Out:
# 10.508761566540327

# %%
clean_test_df2 = clean_test_df

# %%
#Logistic Regression
logPred = log_reg.predict(clean_test_df2)
#Decision Tree
dec_tree_predict = dec_tree.predict(clean_test_df2)
#SVC Predict
svc_predict = svc_model.predict(clean_test_df2)
#Random forest
rf_predict = random_forest.predict(clean_test_df2)
###
dtr_pred = dtr.predict(clean_test_df2)
####
rfr_pred = rfr.predict(clean_test_df2)

# %%
Log_predict_df =pd.DataFrame(logPred)
dec_tree_predict_df =pd.DataFrame(dec_tree_predict)
svc_predict_df =pd.DataFrame(svc_predict)
rf_predict_df =pd.DataFrame(rf_predict)

dtr_predict_df =pd.DataFrame(dtr_pred)
rfr_predict_df =pd.DataFrame(rfr_pred)

# %%
#Adding predictions to our dataset
test_result = test_df
test_result['log_pred'] = Log_predict_df
test_result['tree_pred'] = dec_tree_predict_df
test_result['svc_pred'] = svc_predict_df
test_result['rf_pred'] = rf_predict_df

test_result['dtr_pred'] = dtr_predict_df
test_result['rfr_pred'] = rfr_predict_df

# %%
test_result.head()
# Out:
#      Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0  1461          20       RH    11622   Pave      Reg         Lvl    AllPub
# 1  1462          20       RL    14267   Pave      IR1         Lvl    AllPub
# 2  1463          60       RL    13830   Pave      IR1         Lvl    AllPub
# 3  1464          60       RL     9978   Pave      IR1         Lvl    AllPub
# 4  1465         120       RL     5005   Pave      IR1         HLS    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl        NAmes      Feedr       Norm     1Fam     1Story
# 1    Corner       Gtl        NAmes       Norm       Norm     1Fam     1Story
# 2    Inside       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 3    Inside       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 4    Inside       Gtl      StoneBr       Norm       Norm   TwnhsE     1Story
#
# ...

# %% [markdown]
# # new data as input

# %%
submission =test_df[['Id','log_pred']]
submission = submission.rename(
    columns={
        'log_pred':'SalePrice',
 })
submission
# Out:
#         Id  SalePrice
# 0     1461     135000
# 1     1462     190000
# 2     1463     135000
# 3     1464     135000
# 4     1465     127500
# ...    ...        ...
# 1454  2915     117000
# 1455  2916     117000
# 1456  2917     160000
# 1457  2918     144000
# 1458  2919     193000
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('submission.csv', index=False)
